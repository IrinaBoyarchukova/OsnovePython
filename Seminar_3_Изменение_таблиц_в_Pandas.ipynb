# %% [markdown]
# <a href="https://colab.research.google.com/github/IrinaBoyarchukova/OsnovePython/blob/main/Seminar_3_%D0%98%D0%B7%D0%BC%D0%B5%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5_%D1%82%D0%B0%D0%B1%D0%BB%D0%B8%D1%86_%D0%B2_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('test.csv')
df.dtypes
# Out:
# laptop_ID             int64
# Company              object
# Product              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price_euros         float64
# dtype: object

# %% [markdown]
# #Задание
# * 1.1 Создать новый признак Cpu_Company, который будет содержать только название фирмы, которая произвела CPU (Intel, AMD и т.д)
# * 1.2 Создать новый признак Memory_Amount, который будет содержать только количество Gb памяти без указания типа носителя (128, 1024, 256 и т.д.)
# * 1.3 Создать новый признак Memory_Type, который будет содержать только тип носителя (HDD, SDD и т.д.)
# * 1.4 Удалите признаки Memory и ScreenResolution

# %%
arr = ['Дмитрий', 'Ирина', 'Марина']
print(' @@ '.join(arr))

stroka = 'Дмитрий Ирина Марина'
print(stroka.split('и'))
# Out:
# Дмитрий @@ Ирина @@ Марина
# ['Дм', 'тр', 'й Ир', 'на Мар', 'на']

# %%
users = pd.read_csv('test.csv')
users.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
df['Cpu_Company'] = [j[0] for j in [str(i).split() for i in df['Cpu']]]
df.head(20) # 1.1
# Out:
#     laptop_ID Company            Product   TypeName  Inches  \
# 0           1   Apple        MacBook Pro  Ultrabook    13.3
# 1           2   Apple        Macbook Air  Ultrabook    13.3
# 2           3      HP             250 G6   Notebook    15.6
# 3           4   Apple        MacBook Pro  Ultrabook    15.4
# 4           5   Apple        MacBook Pro  Ultrabook    13.3
# 5           6    Acer           Aspire 3   Notebook    15.6
# 6           7   Apple        MacBook Pro  Ultrabook    15.4
# 7           8   Apple        Macbook Air  Ultrabook    13.3
# 8           9    Asus    ZenBook UX430UN  Ultrabook    14.0
# 9          10    Acer            Swift 3  Ultrabook    14.0
# 10         11      HP             250 G6   Notebook    15.6
# 11         12      HP             250 G6   Notebook    15.6
# 12         13   Apple        MacBook Pro  Ultrabook    15.4
# 13         14    Dell      Inspiron 3567   Notebook    15.6
# 14         15   Apple        MacBook 12"  Ultrabook    12.0
# 15         16   Apple        MacBook Pro  Ultrabook    13.3
# 16         17    Dell      Inspiron 3567   Notebook    15.6
# 17         18   Apple        MacBook Pro  Ultrabook    15.4
# 18         19  Lenovo  IdeaPad 320-15IKB   Notebook    15.6
# 19         20    Dell             XPS 13  Ultrabook    13.3
#
#                              ScreenResolution                         Cpu  \
# 0          IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 1                                    1440x900        Intel Core i5 1.8GHz
# 2                           Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# 3          IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz
# 4          IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
# 5                                    1366x768     AMD A9-Series 9420 3GHz
# 6          IPS Panel Retina Display 2880x1800        Intel Core i7 2.2GHz
# 7                                    1440x900        Intel Core i5 1.8GHz
# 8                           Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
# 9                 IPS Panel Full HD 1920x1080  Intel Core i5 8250U 1.6GHz
# 10                                   1366x768  Intel Core i5 7200U 2.5GHz
# 11                          Full HD 1920x1080    Intel Core i3 6006U 2GHz
# 12         IPS Panel Retina Display 2880x1800        Intel Core i7 2.8GHz
# 13                          Full HD 1920x1080    Intel Core i3 6006U 2GHz
# 14         IPS Panel Retina Display 2304x1440      Intel Core M m3 1.2GHz
# 15         IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 16                          Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
# 17         IPS Panel Retina Display 2880x1800        Intel Core i7 2.9GHz
# 18                          Full HD 1920x1080  Intel Core i3 7100U 2.4GHz
# 19  IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i5 8250U 1.6GHz
#
#      Ram               Memory                           Gpu       OpSys  \
# 0    8GB            128GB SSD  Intel Iris Plus Graphics 640       macOS
# 1    8GB  128GB Flash Storage        Intel HD Graphics 6000       macOS
# 2    8GB            256GB SSD         Intel HD Graphics 620       No OS
# 3   16GB            512GB SSD            AMD Radeon Pro 455       macOS
# 4    8GB            256GB SSD  Intel Iris Plus Graphics 650       macOS
# 5    4GB            500GB HDD                 AMD Radeon R5  Windows 10
# 6   16GB  256GB Flash Storage       Intel Iris Pro Graphics    Mac OS X
# 7    8GB  256GB Flash Storage        Intel HD Graphics 6000       macOS
# 8   16GB            512GB SSD          Nvidia GeForce MX150  Windows 10
# 9    8GB            256GB SSD        Intel UHD Graphics 620  Windows 10
# 10   4GB            500GB HDD         Intel HD Graphics 620       No OS
# 11   4GB            500GB HDD         Intel HD Graphics 520       No OS
# 12  16GB            256GB SSD            AMD Radeon Pro 555       macOS
# 13   4GB            256GB SSD            AMD Radeon R5 M430  Windows 10
# 14   8GB            256GB SSD         Intel HD Graphics 615       macOS
# 15   8GB            256GB SSD  Intel Iris Plus Graphics 640       macOS
# 16   8GB            256GB SSD            AMD Radeon R5 M430  Windows 10
# 17  16GB            512GB SSD            AMD Radeon Pro 560       macOS
# 18   8GB              1TB HDD          Nvidia GeForce 940MX       No OS
# 19   8GB            128GB SSD        Intel UHD Graphics 620  Windows 10
#
#     Weight  Price_euros Cpu_Company
# 0   1.37kg      1339.69       Intel
# 1   1.34kg       898.94       Intel
# 2   1.86kg       575.00       Intel
# 3   1.83kg      2537.45       Intel
# 4   1.37kg      1803.60       Intel
# 5    2.1kg       400.00         AMD
# 6   2.04kg      2139.97       Intel
# 7   1.34kg      1158.70       Intel
# 8    1.3kg      1495.00       Intel
# 9    1.6kg       770.00       Intel
# 10  1.86kg       393.90       Intel
# 11  1.86kg       344.99       Intel
# 12  1.83kg      2439.97       Intel
# 13   2.2kg       498.90       Intel
# 14  0.92kg      1262.40       Intel
# 15  1.37kg      1518.55       Intel
# 16   2.2kg       745.00       Intel
# 17  1.83kg      2858.00       Intel
# 18   2.2kg       499.00       Intel
# 19  1.22kg       979.00       Intel

# %%
df['Memory_Amount'] = [j[0] for j in [str(i).split() for i in df['Memory']]]
df.head(20) # 1.2
# Out:
#     laptop_ID Company            Product   TypeName  Inches  \
# 0           1   Apple        MacBook Pro  Ultrabook    13.3
# 1           2   Apple        Macbook Air  Ultrabook    13.3
# 2           3      HP             250 G6   Notebook    15.6
# 3           4   Apple        MacBook Pro  Ultrabook    15.4
# 4           5   Apple        MacBook Pro  Ultrabook    13.3
# 5           6    Acer           Aspire 3   Notebook    15.6
# 6           7   Apple        MacBook Pro  Ultrabook    15.4
# 7           8   Apple        Macbook Air  Ultrabook    13.3
# 8           9    Asus    ZenBook UX430UN  Ultrabook    14.0
# 9          10    Acer            Swift 3  Ultrabook    14.0
# 10         11      HP             250 G6   Notebook    15.6
# 11         12      HP             250 G6   Notebook    15.6
# 12         13   Apple        MacBook Pro  Ultrabook    15.4
# 13         14    Dell      Inspiron 3567   Notebook    15.6
# 14         15   Apple        MacBook 12"  Ultrabook    12.0
# 15         16   Apple        MacBook Pro  Ultrabook    13.3
# 16         17    Dell      Inspiron 3567   Notebook    15.6
# 17         18   Apple        MacBook Pro  Ultrabook    15.4
# 18         19  Lenovo  IdeaPad 320-15IKB   Notebook    15.6
# 19         20    Dell             XPS 13  Ultrabook    13.3
#
#                              ScreenResolution                         Cpu  \
# 0          IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 1                                    1440x900        Intel Core i5 1.8GHz
# 2                           Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# 3          IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz
# 4          IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
# 5                                    1366x768     AMD A9-Series 9420 3GHz
# 6          IPS Panel Retina Display 2880x1800        Intel Core i7 2.2GHz
# 7                                    1440x900        Intel Core i5 1.8GHz
# 8                           Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
# 9                 IPS Panel Full HD 1920x1080  Intel Core i5 8250U 1.6GHz
# 10                                   1366x768  Intel Core i5 7200U 2.5GHz
# 11                          Full HD 1920x1080    Intel Core i3 6006U 2GHz
# 12         IPS Panel Retina Display 2880x1800        Intel Core i7 2.8GHz
# 13                          Full HD 1920x1080    Intel Core i3 6006U 2GHz
# 14         IPS Panel Retina Display 2304x1440      Intel Core M m3 1.2GHz
# 15         IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 16                          Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
# 17         IPS Panel Retina Display 2880x1800        Intel Core i7 2.9GHz
# 18                          Full HD 1920x1080  Intel Core i3 7100U 2.4GHz
# 19  IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i5 8250U 1.6GHz
#
#      Ram               Memory                           Gpu       OpSys  \
# 0    8GB            128GB SSD  Intel Iris Plus Graphics 640       macOS
# 1    8GB  128GB Flash Storage        Intel HD Graphics 6000       macOS
# 2    8GB            256GB SSD         Intel HD Graphics 620       No OS
# 3   16GB            512GB SSD            AMD Radeon Pro 455       macOS
# 4    8GB            256GB SSD  Intel Iris Plus Graphics 650       macOS
# 5    4GB            500GB HDD                 AMD Radeon R5  Windows 10
# 6   16GB  256GB Flash Storage       Intel Iris Pro Graphics    Mac OS X
# 7    8GB  256GB Flash Storage        Intel HD Graphics 6000       macOS
# 8   16GB            512GB SSD          Nvidia GeForce MX150  Windows 10
# 9    8GB            256GB SSD        Intel UHD Graphics 620  Windows 10
# 10   4GB            500GB HDD         Intel HD Graphics 620       No OS
# 11   4GB            500GB HDD         Intel HD Graphics 520       No OS
# 12  16GB            256GB SSD            AMD Radeon Pro 555       macOS
# 13   4GB            256GB SSD            AMD Radeon R5 M430  Windows 10
# 14   8GB            256GB SSD         Intel HD Graphics 615       macOS
# 15   8GB            256GB SSD  Intel Iris Plus Graphics 640       macOS
# 16   8GB            256GB SSD            AMD Radeon R5 M430  Windows 10
# 17  16GB            512GB SSD            AMD Radeon Pro 560       macOS
# 18   8GB              1TB HDD          Nvidia GeForce 940MX       No OS
# 19   8GB            128GB SSD        Intel UHD Graphics 620  Windows 10
#
#     Weight  Price_euros Cpu_Company Memory_Amount
# 0   1.37kg      1339.69       Intel         128GB
# 1   1.34kg       898.94       Intel         128GB
# 2   1.86kg       575.00       Intel         256GB
# 3   1.83kg      2537.45       Intel         512GB
# 4   1.37kg      1803.60       Intel         256GB
# 5    2.1kg       400.00         AMD         500GB
# 6   2.04kg      2139.97       Intel         256GB
# 7   1.34kg      1158.70       Intel         256GB
# 8    1.3kg      1495.00       Intel         512GB
# 9    1.6kg       770.00       Intel         256GB
# 10  1.86kg       393.90       Intel         500GB
# 11  1.86kg       344.99       Intel         500GB
# 12  1.83kg      2439.97       Intel         256GB
# 13   2.2kg       498.90       Intel         256GB
# 14  0.92kg      1262.40       Intel         256GB
# 15  1.37kg      1518.55       Intel         256GB
# 16   2.2kg       745.00       Intel         256GB
# 17  1.83kg      2858.00       Intel         512GB
# 18   2.2kg       499.00       Intel           1TB
# 19  1.22kg       979.00       Intel         128GB

# %%
df['Memory_Type'] = [' '.join(j[1:]) for j in [str(i).split() for i in df['Memory']]]
df[['Cpu_Company', 'Memory_Amount', 'Memory_Type']] # 1.3
# Out:
#      Cpu_Company Memory_Amount    Memory_Type
# 0          Intel         128GB            SSD
# 1          Intel         128GB  Flash Storage
# 2          Intel         256GB            SSD
# 3          Intel         512GB            SSD
# 4          Intel         256GB            SSD
# ...          ...           ...            ...
# 1298       Intel         128GB            SSD
# 1299       Intel         512GB            SSD
# 1300       Intel          64GB  Flash Storage
# 1301       Intel           1TB            HDD
# 1302       Intel         500GB            HDD
#
# [1303 rows x 3 columns]

# %%
#df.drop(columns=['Memory', 'ScreenResolution'], inplace=True)

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company Memory_Amount    Memory_Type
# 0  1.37kg      1339.69       Intel         128GB            SSD
# 1  1.34kg       898.94       Intel         128GB  Flash Storage
# 2  1.86kg       575.00       Intel         256GB            SSD
# 3  1.83kg      2537.45       Intel         512GB            SSD
# 4  1.37kg      1803.60       Intel         256GB            SSD

# %% [markdown]
# # Задание 2
# * 2.1 Создайте признак SSD, который изначально равен 0
# * 2.2 Поставьте в признаке SSD 1, если ноутбук действительно с типом носителя SSD
# * 2.3 Уберите в признаке Weight значения 'kg' и поменяйте его тип данных на вещественный

# %% [markdown]
# # 2.1

# %%
df['SSD'] = 0

# %% [markdown]
# # 2.2

# %%
df['SSD'] = [int('SSD' == i) for i in df['Memory_Type']]

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company Memory_Amount    Memory_Type  SSD
# 0  1.37kg      1339.69       Intel         128GB            SSD    1
# 1  1.34kg       898.94       Intel         128GB  Flash Storage    0
# 2  1.86kg       575.00       Intel         256GB            SSD    1
# 3  1.83kg      2537.45       Intel         512GB            SSD    1
# 4  1.37kg      1803.60       Intel         256GB            SSD    1

# %% [markdown]
# # 2.3

# %%
#df['Weight'] = [float(i.split('kg')[0]) for i in df['Weight']]
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company Memory_Amount    Memory_Type  SSD
# 0    1.37      1339.69       Intel         128GB            SSD    1
# 1    1.34       898.94       Intel         128GB  Flash Storage    0
# 2    1.86       575.00       Intel         256GB            SSD    1
# 3    1.83      2537.45       Intel         512GB            SSD    1
# 4    1.37      1803.60       Intel         256GB            SSD    1

# %% [markdown]
# # Задание 3
# Создайте датафрейм с клиентами:
# clients = pd.DataFrame({
#     'client_id': [45, 32, 67, 33, 43],
#     'laptop_id': [506, 398, 710, 120, 1999]
# })
# laptop_id - это индексы датафрейма с ноутбуками
# 3.1 Присоедините к таблице clients данные по ноутбукам через метод join
# 3.2 Присоедините к таблице clients данные по ноутбукам через метод merge
# Это нужно, чтобы понимать, какие ноутбуки покупались клиентами

# %%
clients = pd.DataFrame({
    'client_id': [45, 32, 67, 33, 43],
    'laptop_id': [506, 398, 710, 120, 1999]
})

# %%
clients.head()
# Out:
#    client_id  laptop_id
# 0         45        506
# 1         32        398
# 2         67        710
# 3         33        120
# 4         43       1999

# %% [markdown]
# 3.1

# %%
clients_id = clients.set_index('client_id')
df_id = df.set_index('laptop_ID')
clients_id.join(df_id).head()
# Out:
#            laptop_id Company                                 Product  \
# client_id
# 45               506    Dell                           Inspiron 7773
# 32               398    Asus    E402WA-GA010T (E2-6110/2GB/32GB/W10)
# 67               710    Asus                             ZenBook Pro
# 33               120      HP    17-ak001nv (A6-9220/4GB/500GB/Radeon
# 43              1999    Asus  X542UQ-GO005 (i5-7200U/8GB/1TB/GeForce
#
#                      TypeName  Inches                          Cpu   Ram  \
# client_id
# 45         2 in 1 Convertible    17.3   Intel Core i5 8250U 1.6GHz  12GB
# 32                   Notebook    14.0  AMD E-Series E2-6110 1.5GHz   2GB
# 67                  Ultrabook    15.6  Intel Core i7 7700HQ 2.8GHz  16GB
# 33                   Notebook    17.3    AMD A6-Series 9220 2.5GHz   4GB
# 43                   Notebook    15.6   Intel Core i5 7200U 2.5GHz   8GB
#
#                                   Gpu       OpSys  Weight  Price_euros  \
# client_id
# 45               Nvidia GeForce 150MX  Windows 10    2.77       999.00
# 32                      AMD Radeon R2  Windows 10    1.65       199.00
# 67         Nvidia GeForce GTX 1050 Ti  Windows 10    1.80      1983.00
# 33                     AMD Radeon 530  Windows 10    2.71       439.00
# 43               Nvidia GeForce 940MX       Linux    2.30       522.99
#
#           Cpu_Company Memory_Amount    Memory_Type  SSD
# client_id
# 45              Intel           1TB            HDD    0
# 32                AMD          32GB  Flash Storage    0
# 67              Intel         512GB            SSD    1
# 33                AMD         500GB            HDD    0
# 43              Intel           1TB            HDD    0

# %% [markdown]
# 3.2

# %%
merged = clients.merge(df, left_on='laptop_id', right_on='laptop_ID')
merged.head()
# Out:
#    client_id  laptop_id  laptop_ID Company            Product  TypeName  \
# 0         45        506        506  Lenovo      ThinkPad L570  Notebook
# 1         67        710        710  Lenovo  IdeaPad 320-15ABR  Notebook
# 2         33        120        120    Dell      Inspiron 7570  Notebook
#
#    Inches                          Cpu  Ram                    Gpu  \
# 0    15.6   Intel Core i5 7200U 2.5GHz  8GB  Intel HD Graphics 620
# 1    15.6  AMD A12-Series 9720P 3.6GHz  8GB          AMD Radeon R7
# 2    15.6   Intel Core i7 8550U 1.8GHz  8GB   Nvidia GeForce 940MX
#
#         OpSys  Weight  Price_euros Cpu_Company Memory_Amount    Memory_Type  \
# 0  Windows 10    2.30       911.00       Intel         256GB            SSD
# 1  Windows 10    2.20       429.00         AMD           1TB            HDD
# 2  Windows 10    2.16      1130.33       Intel         256GB  SSD + 1TB HDD
#
#    SSD
# 0    1
# 1    0
# 2    0

# %% [markdown]
# # Задание 4 Составьте несколько сводных таблиц
# * 4.1 Найдите среднюю стоимость ноутбуков в зависимости от компании производителя
# Отсортируйте от меньшей стоимости к большей
# * 4.2 Найдите минимальную, среднюю и максимальную стоимости ноутбуков в зависимости от производителя процессора
# * 4.3 Постройте таблицу с подсчетом количества ноутбуков в данных в зависимости от производителя CPU и ОЗУ
# * 4.4 Постройте таблицу с подсчетом средней стоимости ноутбуков в данных в зависимости от операционной системы и GB памяти

# %% [markdown]
# #4.1

# %%
newData = df.groupby('Cpu_Company').agg({'Price_euros': ['mean']})
newData['Price_euros'].sort_values('mean')
# Out:
#                     mean
# Cpu_Company
# AMD           560.638871
# Samsung       659.000000
# Intel        1152.214145

# %% [markdown]
# # 4.2

# %%
df.groupby('Cpu_Company').agg({'Price_euros': ['mean', 'min', 'max']})
# Out:
#              Price_euros
#                     mean    min     max
# Cpu_Company
# AMD           560.638871  199.0  2199.0
# Intel        1152.214145  174.0  6099.0
# Samsung       659.000000  659.0   659.0

# %% [markdown]
# #4.3

# %%
pd.crosstab(index=df['Cpu_Company'], columns=df['Ram'])
# Out:
# Ram          12GB  16GB  24GB  2GB  32GB  4GB  64GB  6GB  8GB
# Cpu_Company
# AMD             2     3     0    1     0   31     0   13   12
# Intel          23   197     3   21    17  343     1   28  607
# Samsung         0     0     0    0     0    1     0    0    0

# %% [markdown]
# #4.4

# %%
df.pivot_table(index='Cpu_Company', columns='Memory_Amount', aggfunc='mean', values='Price_euros')
# Out:
# Memory_Amount       1.0TB        128GB    16GB   180GB         1TB   240GB  \
# Cpu_Company
# AMD            549.990000   487.850000     NaN     NaN  484.778571     NaN
# Intel          873.498571  1031.640414  305.38  1098.6  860.295133  3100.0
# Samsung               NaN          NaN     NaN     NaN         NaN     NaN
#
# Memory_Amount        256GB         2TB        32GB       500GB   508GB  \
# Cpu_Company
# AMD             796.871250  688.002500  199.000000  345.615385     NaN
# Intel          1350.772236  635.613333  299.047674  658.763782  1002.0
# Samsung                NaN         NaN  659.000000         NaN     NaN
#
# Memory_Amount       512GB    64GB     8GB
# Cpu_Company
# AMD             974.00000  277.99     NaN
# Intel          1934.57913  533.01  2249.0
# Samsung               NaN     NaN     NaN

# %% [markdown]
# # Задание 5
#
#
# * 5.1 Ноутбуков каких компаний и с каким процессором больше?
# * 5.2 С каким типом памяти и с каким объемом памяти больше ноутбуков?

# %% [markdown]
# # 5.1

# %%
pd.crosstab(index=df['Cpu'], columns=df['Company'])
# Out:
# Company                               Acer  Apple  Asus  Chuwi  Dell  Fujitsu  \
# Cpu
# AMD A10-Series 9600P 2.4GHz              0      0     0      0     0        0
# AMD A10-Series 9620P 2.5GHz              1      0     0      0     0        0
# AMD A10-Series A10-9620P 2.5GHz          0      0     1      0     0        0
# AMD A12-Series 9700P 2.5GHz              0      0     0      0     0        0
# AMD A12-Series 9720P 2.7GHz              1      0     0      0     0        0
# ...                                    ...    ...   ...    ...   ...      ...
# Intel Pentium Quad Core N4200 1.1GHz     3      0     5      0     1        0
# Intel Xeon E3-1505M V6 3GHz              0      0     0      0     2        0
# Intel Xeon E3-1535M v5 2.9GHz            0      0     0      0     0        0
# Intel Xeon E3-1535M v6 3.1GHz            0      0     0      0     0        0
# Samsung Cortex A72&A53 2.0GHz            0      0     0      0     0        0
#
# Company                               Google  HP  Huawei  LG  Lenovo  MSI  \
# Cpu
# AMD A10-Series 9600P 2.4GHz                0   1       0   0       1    0
# AMD A10-Series 9620P 2.5GHz                0   1       0   0       0    0
# AMD A10-Series A10-9620P 2.5GHz            0   1       0   0       0    0
# AMD A12-Series 9700P 2.5GHz                0   1       0   0       0    0
# AMD A12-Series 9720P 2.7GHz                0   1       0   0       0    0
# ...                                      ...  ..     ...  ..     ...  ...
# Intel Pentium Quad Core N4200 1.1GHz       0   1       0   0       4    0
# Intel Xeon E3-1505M V6 3GHz                0   0       0   0       0    0
# Intel Xeon E3-1535M v5 2.9GHz              0   1       0   0       0    0
# Intel Xeon E3-1535M v6 3.1GHz              0   0       0   0       1    0
# Samsung Cortex A72&A53 2.0GHz              0   0       0   0       0    0
#
# Company                               Mediacom  Microsoft  Razer  Samsung  \
# Cpu
# AMD A10-Series 9600P 2.4GHz                  0          0      0        0
# AMD A10-Series 9620P 2.5GHz                  0          0      0        0
# AMD A10-Series A10-9620P 2.5GHz              0          0      0        0
# AMD A12-Series 9700P 2.5GHz                  0          0      0        0
# AMD A12-Series 9720P 2.7GHz                  0          0      0        0
# ...                                        ...        ...    ...      ...
# Intel Pentium Quad Core N4200 1.1GHz         0          0      0        0
# Intel Xeon E3-1505M V6 3GHz                  0          0      0        0
# Intel Xeon E3-1535M v5 2.9GHz                0          0      0        0
# Intel Xeon E3-1535M v6 3.1GHz                0          0      0        0
# Samsung Cortex A72&A53 2.0GHz                0          0      0        1
#
# Company                               Toshiba  Vero  Xiaomi
# Cpu
# AMD A10-Series 9600P 2.4GHz                 0     0       0
# AMD A10-Series 9620P 2.5GHz                 0     0       0
# AMD A10-Series A10-9620P 2.5GHz             0     0       0
# AMD A12-Series 9700P 2.5GHz                 0     0       0
# AMD A12-Series 9720P 2.7GHz                 0     0       0
# ...                                       ...   ...     ...
# Intel Pentium Quad Core N4200 1.1GHz        0     0       0
# Intel Xeon E3-1505M V6 3GHz                 0     0       0
# Intel Xeon E3-1535M v5 2.9GHz               0     0       0
# Intel Xeon E3-1535M v6 3.1GHz               0     0       0
# Samsung Cortex A72&A53 2.0GHz               0     0       0
#
# [118 rows x 19 columns]

# %% [markdown]
# # 5.2

# %%
pd.crosstab(index=df['Cpu'], columns=df['Company']).max()
# Out:
# Company
# Acer         11
# Apple         3
# Asus         30
# Chuwi         1
# Dell         44
# Fujitsu       2
# Google        2
# HP           45
# Huawei        1
# LG            2
# Lenovo       54
# MSI          30
# Mediacom      3
# Microsoft     2
# Razer         3
# Samsung       5
# Toshiba      15
# Vero          2
# Xiaomi        1
# dtype: int64
